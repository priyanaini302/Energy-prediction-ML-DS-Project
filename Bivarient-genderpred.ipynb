# %% [markdown]
# # Covarience & correlation

# %%
import pandas as pd

# %%
dataset=pd.read_csv('Pre_processdata.csv')

# %%
dataset
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             1               14.0                 5.4          0          0
# 2             1               11.8                 6.3          1          1
# 3             1               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 0             1                          1    Male
# 1             1                          0  Female
# 2             1                          1    Male
# 3             1                          1    Male
# 4             0                          0  Female
# ...         ...                        ...     ...
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male
#
# [5001 rows x 8 columns]

# %%
dataset.isna().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
dataset.corr()
# Out:
#                            long_hair  forehead_width_cm  forehead_height_cm  \
# long_hair                        NaN                NaN                 NaN
# forehead_width_cm                NaN           1.000000            0.088596
# forehead_height_cm               NaN           0.088596            1.000000
# nose_wide                        NaN           0.251648            0.211655
# nose_long                        NaN           0.257368            0.194120
# lips_thin                        NaN           0.258564            0.205441
# distance_nose_to_lip_long        NaN           0.251328            0.215292
#
#                            nose_wide  nose_long  lips_thin  \
# long_hair                        NaN        NaN        NaN
# forehead_width_cm           0.251648   0.257368   0.258564
# forehead_height_cm          0.211655   0.194120   0.205441
# nose_wide                   1.000000   0.565192   0.557615
# nose_long                   0.565192   1.000000   0.561229
# lips_thin                   0.557615   0.561229   1.000000
# distance_nose_to_lip_long   0.569303   0.559794   0.565312
#
#                            distance_nose_to_lip_long
# long_hair                                        NaN
# forehead_width_cm                           0.251328
# forehead_height_cm                          0.215292
# nose_wide                                   0.569303
# nose_long                                   0.559794
# lips_thin                                   0.565312
# distance_nose_to_lip_long                   1.000000

# %%
dataset.cov()
# Out:
#                            long_hair  forehead_width_cm  forehead_height_cm  \
# long_hair                        0.0           0.000000            0.000000
# forehead_width_cm                0.0           1.225733            0.053092
# forehead_height_cm               0.0           0.053092            0.292971
# nose_wide                        0.0           0.139307            0.057282
# nose_long                        0.0           0.142466            0.052534
# lips_thin                        0.0           0.143132            0.055600
# distance_nose_to_lip_long        0.0           0.139140            0.058271
#
#                            nose_wide  nose_long  lips_thin  \
# long_hair                   0.000000   0.000000   0.000000
# forehead_width_cm           0.139307   0.142466   0.143132
# forehead_height_cm          0.057282   0.052534   0.055600
# nose_wide                   0.250013   0.141298   0.139408
# nose_long                   0.141298   0.249988   0.140304
# lips_thin                   0.139408   0.140304   0.250002
# distance_nose_to_lip_long   0.142343   0.139959   0.141342
#
#                            distance_nose_to_lip_long
# long_hair                                   0.000000
# forehead_width_cm                           0.139140
# forehead_height_cm                          0.058271
# nose_wide                                   0.142343
# nose_long                                   0.139959
# lips_thin                                   0.141342
# distance_nose_to_lip_long                   0.250049

# %% [markdown]
# # Multicolinearity  -- It occurs means we can use varience inflation factor(vif)

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)
